# %%
import torch
import tensorflow as tf
tf.config.get_visible_devices()
# Out:
# 2024-04-28 13:59:28.715351: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-28 13:59:28.715376: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-28 13:59:28.715390: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-28 13:59:28.720440: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-28 13:59:29.921088: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-28 13:59:29.921712: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-28 13:59:29.921793: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import numpy as np
import pandas as pd
import os, time, re
import pickle, gzip, datetime

from datetime import datetime

now = datetime.now()

import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()
import matplotlib as mpl
# %matplotlib inline


from sklearn import preprocessing as pp
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import log_loss
from sklearn.metrics import precision_recall_curve, average_precision_score
from sklearn.metrics import roc_curve, auc, roc_auc_score, mean_squared_error
import lightgbm as lgb

import tensorflow as tf
import keras

from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Activation, Dense, Dropout
from tensorflow.keras.layers import BatchNormalization, Input, Lambda
from tensorflow.keras.layers import Embedding, Flatten, dot
from tensorflow.keras import regularizers
from tensorflow.keras.losses import mse, binary_crossentropy

# %%
#!/usr/bin/env python
# coding: utf-8
"""
This is a example of MAG generation and data processing on the MovieLens dataset.
"""

import numpy as np
import csv
import pandas as pd
import random
import pickle
import copy
from scipy.sparse import csr_matrix

np.random.seed(2023)
random.seed(2023)

path = 'ratings.dat'
reviews_df  = pd.read_csv(path,sep='::',header=None)
reviews_df.columns = ['user_id','item_id','rating','timestamp']
# reviews_df.loc[:,'rating'] = reviews_df['rating'].map(lambda x: 1 if x >= 4 else 0)

# reindex of the IDs
def build_map(df, col_name):
    key = sorted(df[col_name].unique().tolist())
    m = dict(zip(key, range(1,len(key)+1)))
    df.loc[:,col_name] = df[col_name].map(lambda x: m[x])
    return m, key


uid_map, uid_key = build_map(reviews_df, 'user_id')


path = 'movies.dat'
meta_df  = pd.read_csv(path,sep='::',header=None)
meta_df.columns = ['item_id','title','genres']
meta_df = meta_df[['item_id', 'genres']]
meta_df.loc[:,'genres'] = meta_df['genres'].map(lambda x: x.split('|')[0])

vid_map, vid_key = build_map(meta_df, 'item_id')
cat_map, cat_key = build_map(meta_df, 'genres')

user_count, item_count, cate_count, example_count =    len(uid_map), len(vid_map), len(cat_map), reviews_df.shape[0]
print('user_count: %d\titem_count: %d\tcate_count: %d\texample_count: %d' %
      (user_count, item_count, cate_count, example_count))

meta_df = meta_df.sort_values('item_id')
meta_df = meta_df.reset_index(drop=True)

reviews_df['item_id'] = reviews_df['item_id'].map(lambda x: vid_map[x])
reviews_df = reviews_df.sort_values(['user_id', 'timestamp'])
reviews_df = reviews_df.reset_index(drop=True)

cate_list = [meta_df['genres'][i] for i in range(len(vid_map))]
cate_list = np.array(cate_list, dtype=np.int32)

cate_list = np.insert(cate_list, 0, 0)

with open('remap.pkl', 'wb') as f:
    pickle.dump(reviews_df, f, pickle.HIGHEST_PROTOCOL) # uid, iid, time(sorted)
    pickle.dump(cate_list, f, pickle.HIGHEST_PROTOCOL) # cid of iid line
    pickle.dump((user_count, item_count, cate_count, example_count),
              f, pickle.HIGHEST_PROTOCOL)
    pickle.dump((vid_key, cat_key, uid_key), f, pickle.HIGHEST_PROTOCOL)
# Out:
# /tmp/ipykernel_284942/379272165.py:19: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   reviews_df  = pd.read_csv(path,sep='::',header=None)
# /tmp/ipykernel_284942/379272165.py:35: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   meta_df  = pd.read_csv(path,sep='::',header=None)
# user_count: 69878	item_count: 10681	cate_count: 20	example_count: 10000054

# %%
reviews_df
# Out:
#           user_id  item_id  rating  timestamp
# 0               1      583     5.0  838983339
# 1               1      229     5.0  838983392
# 2               1      314     5.0  838983392
# 3               1      326     5.0  838983392
# 4               1      290     5.0  838983421
# ...           ...      ...     ...        ...
# 10000049    69878     1753     3.0  912649171
# 10000050    69878      258     5.0  912649271
# 10000051    69878     1662     4.0  912649271
# 10000052    69878      882     4.0  912649403
# 10000053    69878     1172     4.0  912649434
#
# [10000054 rows x 4 columns]

# %%
pos_cnt, neg_cnt = 0, 0
for userId, hist in reviews_df.groupby('user_id'):
    movie_list = hist['item_id'].tolist()
    label_list = hist['rating'].tolist()

    pos_cnt += sum(label_list)
    neg_cnt += len(label_list) - sum(label_list)
    
train_hist_time, test_time = list(np.quantile(reviews_df.timestamp, [0.80, 0.90]))
train_df = reviews_df[reviews_df.timestamp <= test_time]
test_df = reviews_df[reviews_df.timestamp > test_time]

if train_df.shape[0]+test_df.shape[0] == reviews_df.shape[0]:
    print("Split Correct!")
else:
    print("Split Error!")
# Out:
# Split Correct!

# %%
train_df
# Out:
#           user_id  item_id  rating  timestamp
# 0               1      583     5.0  838983339
# 1               1      229     5.0  838983392
# 2               1      314     5.0  838983392
# 3               1      326     5.0  838983392
# 4               1      290     5.0  838983421
# ...           ...      ...     ...        ...
# 10000049    69878     1753     3.0  912649171
# 10000050    69878      258     5.0  912649271
# 10000051    69878     1662     4.0  912649271
# 10000052    69878      882     4.0  912649403
# 10000053    69878     1172     4.0  912649434
#
# [9000048 rows x 4 columns]

# %%
test_df
# Out:
#          user_id  item_id  rating   timestamp
# 4425          32     5254     4.0  1208669626
# 4426          32     9707     2.0  1208669698
# 4427          32     3477     4.5  1208669735
# 4428          32     1662     3.0  1208669755
# 4429          32      641     3.0  1208669784
# ...          ...      ...     ...         ...
# 9999654    69873     2123     4.0  1216573669
# 9999655    69873     2097     4.0  1216573677
# 9999656    69873     2101     4.5  1216573680
# 9999657    69873     3283     5.0  1216575007
# 9999658    69873    10663     1.0  1230356073
#
# [1000006 rows x 4 columns]

# %%
train_eval_df = reviews_df[(reviews_df.timestamp > train_hist_time) & (reviews_df.timestamp <= test_time)]

# %%
train_eval_df
# Out:
#          user_id  item_id  rating   timestamp
# 69             3     4443     4.0  1164885526
# 70             3     7042     3.5  1164885564
# 71             3     3323     4.0  1164885590
# 72             3     5204     3.0  1164885617
# 73             3     5432     4.5  1164885648
# ...          ...      ...     ...         ...
# 9999697    69874     4291     4.5  1162134523
# 9999698    69874     5890     4.0  1162134604
# 9999699    69874     2806     3.5  1162134613
# 9999700    69874     9119     3.5  1162134964
# 9999701    69874     9460     4.5  1162135290
#
# [1000005 rows x 4 columns]

# %%
train_trai_df = reviews_df[reviews_df.timestamp < train_hist_time]

# %% [raw]
# train_trai_df

# %%
# train_matrix = train_df.pivot(index='user_id', columns='item_id', values='rating')
train_matrix = np.zeros((user_count+1, item_count+1))
for row in train_df.to_numpy():
    train_matrix[int(row[0]),int(row[1])]=row[2]

# %%
train_matrix.shape
# Out:
# (69879, 10682)

# %%
train_matrix[1,583]
# Out:
# 5.0

# %%
test_matrix = np.zeros((user_count+1, item_count+1))
for row in test_df.to_numpy():
    test_matrix[int(row[0]),int(row[1])]=row[2]

# %% [markdown]
# baseline experiments

# %%
actual_test = test_matrix[test_matrix.nonzero()].flatten()

# %%
actual_test.size
# Out:
# 1000006

# %%
actual_test
# Out:
# array([3. , 3. , 3. , ..., 4.5, 4.5, 1. ])

# %%
min(actual_test)
# Out:
# 0.5

# %%
pred_test = np.zeros(actual_test.size)
pred_test[pred_test==0] = 3.5
pred_test
# Out:
# array([3.5, 3.5, 3.5, ..., 3.5, 3.5, 3.5])

# %%
pred_test.size
# Out:
# 1000006

# %%
print("Mean  Squared Error is : ", mean_squared_error(pred_test, actual_test))
# Out:
# Mean  Squared Error is :  1.016053153681078

# %%
n_factors  = 10

# %%
## Initializing a input layer for users
user = tf.keras.layers.Input(shape = (1,))

## Embedding layer for n_factors of users
u = keras.layers.Embedding(user_count, n_factors, embeddings_initializer = 'he_normal', embeddings_regularizer = tf.keras.regularizers.l2(1e-6))(user)
u = tf.keras.layers.Reshape((n_factors,))(u)

## Initializing a input layer for movies
movie = tf.keras.layers.Input(shape = (1,))

## Embedding layer for n_factors of movies
m = keras.layers.Embedding(item_count, n_factors, embeddings_initializer = 'he_normal', embeddings_regularizer=tf.keras.regularizers.l2(1e-6))(movie)
m = tf.keras.layers.Reshape((n_factors,))(m)

## stacking up both user and movie embeddings
x = tf.keras.layers.Concatenate()([u,m])
x = tf.keras.layers.Dropout(0.05)(x)

## Adding a Dense layer to the architecture
x = tf.keras.layers.Dense(32, kernel_initializer='he_normal')(x)
x = tf.keras.layers.Activation(activation='relu')(x)
x = tf.keras.layers.Dropout(0.05)(x)

x = tf.keras.layers.Dense(16, kernel_initializer='he_normal')(x)
x = tf.keras.layers.Activation(activation='relu')(x)
x = tf.keras.layers.Dropout(0.05)(x)

## Adding an Output layer with Sigmoid activation funtion which gives output between 0 and 1
x = tf.keras.layers.Dense(9)(x)
x = tf.keras.layers.Activation(activation='softmax')(x)

## Defining the model
model = tf.keras.models.Model(inputs=[user,movie], outputs=x)

model.compile(optimizer=keras.optimizers.Nadam(
    learning_rate=1e-4,
), loss=tf.keras.losses.SparseCategoricalCrossentropy(), metrics=['accuracy'])
# Out:
# 2024-04-28 14:00:27.073684: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-28 14:00:27.073805: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-28 14:00:27.073873: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-28 14:00:27.113943: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-28 14:00:27.114044: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-28 14:00:27.114121: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-28 14:00:27.114180: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4925 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 1)]                  0         []
#
#  input_2 (InputLayer)        [(None, 1)]                  0         []
#
#  embedding (Embedding)       (None, 1, 10)                698780    ['input_1[0][0]']
#
#  embedding_1 (Embedding)     (None, 1, 10)                106810    ['input_2[0][0]']
#
#  reshape (Reshape)           (None, 10)                   0         ['embedding[0][0]']
#
#  reshape_1 (Reshape)         (None, 10)                   0         ['embedding_1[0][0]']
#
#  concatenate (Concatenate)   (None, 20)                   0         ['reshape[0][0]',
#                                                                      'reshape_1[0][0]']
#
#  dropout (Dropout)           (None, 20)                   0         ['concatenate[0][0]']
#
#  dense (Dense)               (None, 32)                   672       ['dropout[0][0]']
#
#  activation (Activation)     (None, 32)                   0         ['dense[0][0]']
#
#  dropout_1 (Dropout)         (None, 32)                   0         ['activation[0][0]']
#
#  dense_1 (Dense)             (None, 16)                   528       ['dropout_1[0][0]']
#
#  activation_1 (Activation)   (None, 16)                   0         ['dense_1[0][0]']
#
#  dropout_2 (Dropout)         (None, 16)                   0         ['activation_1[0][0]']
#
#  dense_2 (Dense)             (None, 9)                    153       ['dropout_2[0][0]']
#
#  activation_2 (Activation)   (None, 9)                    0         ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 806943 (3.08 MB)
# Trainable params: 806943 (3.08 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
import torch

# %%
train_df
# Out:
#           user_id  item_id  rating  timestamp
# 0               1      583     5.0  838983339
# 1               1      229     5.0  838983392
# 2               1      314     5.0  838983392
# 3               1      326     5.0  838983392
# 4               1      290     5.0  838983421
# ...           ...      ...     ...        ...
# 10000049    69878     1753     3.0  912649171
# 10000050    69878      258     5.0  912649271
# 10000051    69878     1662     4.0  912649271
# 10000052    69878      882     4.0  912649403
# 10000053    69878     1172     4.0  912649434
#
# [9000048 rows x 4 columns]

# %%
train_eval_df
# Out:
#          user_id  item_id  rating   timestamp
# 69             3     4443     4.0  1164885526
# 70             3     7042     3.5  1164885564
# 71             3     3323     4.0  1164885590
# 72             3     5204     3.0  1164885617
# 73             3     5432     4.5  1164885648
# ...          ...      ...     ...         ...
# 9999697    69874     4291     4.5  1162134523
# 9999698    69874     5890     4.0  1162134604
# 9999699    69874     2806     3.5  1162134613
# 9999700    69874     9119     3.5  1162134964
# 9999701    69874     9460     4.5  1162135290
#
# [1000005 rows x 4 columns]

# %%
train_trai_df
# Out:
#           user_id  item_id  rating  timestamp
# 0               1      583     5.0  838983339
# 1               1      229     5.0  838983392
# 2               1      314     5.0  838983392
# 3               1      326     5.0  838983392
# 4               1      290     5.0  838983421
# ...           ...      ...     ...        ...
# 10000049    69878     1753     3.0  912649171
# 10000050    69878      258     5.0  912649271
# 10000051    69878     1662     4.0  912649271
# 10000052    69878      882     4.0  912649403
# 10000053    69878     1172     4.0  912649434
#
# [8000043 rows x 4 columns]

# %%
train_df
# Out:
#           user_id  item_id  rating  timestamp
# 0               1      583     5.0  838983339
# 1               1      229     5.0  838983392
# 2               1      314     5.0  838983392
# 3               1      326     5.0  838983392
# 4               1      290     5.0  838983421
# ...           ...      ...     ...        ...
# 10000049    69878     1753     3.0  912649171
# 10000050    69878      258     5.0  912649271
# 10000051    69878     1662     4.0  912649271
# 10000052    69878      882     4.0  912649403
# 10000053    69878     1172     4.0  912649434
#
# [9000048 rows x 4 columns]

# %%
train_df.user_id.to_numpy()
# Out:
# array([    1,     1,     1, ..., 69878, 69878, 69878])

# %%
history = model.fit(x=[train_df.user_id, train_df.item_id],
                    y=train_df.rating, epochs=50, batch_size = 256,
                    validation_data=([train_eval_df.user_id,
                                      train_eval_df.item_id], train_eval_df.rating),
                    verbose=1)
# Out:
# Epoch 1/50
# 2024-04-28 14:00:29.116437: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f7501985720 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-04-28 14:00:29.116457: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3070, Compute Capability 8.6
# 2024-04-28 14:00:29.124069: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-04-28 14:00:29.131622: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8700
# 2024-04-28 14:00:29.230015: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 35157/35157 [==============================] - 100s 3ms/step - loss: 1.2775 - accuracy: 0.3695 - val_loss: 1.1851 - val_accuracy: 0.2906
# Epoch 2/50
# 35157/35157 [==============================] - 98s 3ms/step - loss: 1.2019 - accuracy: 0.3938 - val_loss: 1.1597 - val_accuracy: 0.2939
# Epoch 3/50
# 35157/35157 [==============================] - 97s 3ms/step - loss: 1.1854 - accuracy: 0.3986 - val_loss: 1.1469 - val_accuracy: 0.2948
# Epoch 4/50
# 35157/35157 [==============================] - 98s 3ms/step - loss: 1.1780 - accuracy: 0.4011 - val_loss: 1.1412 - val_accuracy: 0.2956
# Epoch 5/50
# 35157/35157 [==============================] - 97s 3ms/step - loss: 1.1741 - accuracy: 0.4029 - val_loss: 1.1374 - val_accuracy: 0.2982
# Epoch 6/50
# 35157/35157 [==============================] - 98s 3ms/step - loss: 1.1708 - accuracy: 0.4048 - val_loss: 1.1347 - val_accuracy: 0.2990
# Epoch 7/50
# 35157/35157 [==============================] - 97s 3ms/step - loss: 1.1683 - accuracy: 0.4061 - val_loss: 1.1325 - val_accuracy: 0.3001
# Epoch 8/50
# 35157/35157 [==============================] - 97s 3ms/step - loss: 1.1658 - accuracy: 0.4075 - val_loss: 1.1295 - val_accuracy: 0.3013
# Epoch 9/50
# 35157/35157 [==============================] - 97s 3ms/step - loss: 1.1636 - accuracy: 0.4086 - val_loss: 1.1271 - val_accuracy: 0.3026
# Epoch 10/50
# 35157/35157 [==============================] - 86s 2ms/step - loss: 1.1617 - accuracy: 0.4098 - val_loss: 1.1251 - val_accuracy: 0.3027
# Epoch 11/50
# 35157/35157 [==============================] - 64s 2ms/step - loss: 1.1604 - accuracy: 0.4106 - val_loss: 1.1232 - val_accuracy: 0.3027
# Epoch 12/50
# 35157/35157 [==============================] - 64s 2ms/step - loss: 1.1590 - accuracy: 0.4115 - val_loss: 1.1231 - val_accuracy: 0.3051
# Epoch 13/50
# 35157/35157 [==============================] - 64s 2ms/step - loss: 1.1582 - accuracy: 0.4122 - val_loss: 1.1211 - val_accuracy: 0.3051
# Epoch 14/50
# 35157/35157 [==============================] - 64s 2ms/step - loss: 1.1575 - accuracy: 0.4129 - val_loss: 1.1200 - val_accuracy: 0.3035
# Epoch 15/50
# 35157/35157 [==============================] - 64s 2ms/step - loss: 1.1571 - accuracy: 0.4134 - val_loss: 1.1198 - val_accuracy: 0.3061
# Epoch 16/50
# 35157/35157 [==============================] - 67s 2ms/step - loss: 1.1568 - accuracy: 0.4137 - val_loss: 1.1202 - val_accuracy: 0.3067
# Epoch 17/50
# 35157/35157 [==============================] - 89s 3ms/step - loss: 1.1566 - accuracy: 0.4142 - val_loss: 1.1195 - val_accuracy: 0.3067
# Epoch 18/50
# 35157/35157 [==============================] - 97s 3ms/step - loss: 1.1564 - accuracy: 0.4145 - val_loss: 1.1193 - val_accuracy: 0.3071
# Epoch 19/50
# 35157/35157 [==============================] - 97s 3ms/step - loss: 1.1566 - accuracy: 0.4147 - val_loss: 1.1189 - val_accuracy: 0.3071
# Epoch 20/50
# 35157/35157 [==============================] - 97s 3ms/step - loss: 1.1564 - accuracy: 0.4150 - val_loss: 1.1186 - val_accuracy: 0.3074
# Epoch 21/50
# 35157/35157 [==============================] - 97s 3ms/step - loss: 1.1566 - accuracy: 0.4151 - val_loss: 1.1181 - val_accuracy: 0.3073
# Epoch 22/50
# 35157/35157 [==============================] - 97s 3ms/step - loss: 1.1566 - accuracy: 0.4155 - val_loss: 1.1182 - val_accuracy: 0.3082
# Epoch 23/50
# 35157/35157 [==============================] - 97s 3ms/step - loss: 1.1567 - accuracy: 0.4155 - val_loss: 1.1177 - val_accuracy: 0.3078
# Epoch 24/50
# 35157/35157 [==============================] - 97s 3ms/step - loss: 1.1568 - accuracy: 0.4158 - val_loss: 1.1177 - val_accuracy: 0.3087
# Epoch 25/50
# 35157/35157 [==============================] - 97s 3ms/step - loss: 1.1570 - accuracy: 0.4157 - val_loss: 1.1178 - val_accuracy: 0.3088
# Epoch 26/50
# 35157/35157 [==============================] - 97s 3ms/step - loss: 1.1571 - accuracy: 0.4157 - val_loss: 1.1179 - val_accuracy: 0.3090
# Epoch 27/50
# 35157/35157 [==============================] - 97s 3ms/step - loss: 1.1574 - accuracy: 0.4158 - val_loss: 1.1179 - val_accuracy: 0.3093
# Epoch 28/50
# 35157/35157 [==============================] - 97s 3ms/step - loss: 1.1575 - accuracy: 0.4159 - val_loss: 1.1172 - val_accuracy: 0.3088
# Epoch 29/50
# 35157/35157 [==============================] - 97s 3ms/step - loss: 1.1576 - accuracy: 0.4160 - val_loss: 1.1180 - val_accuracy: 0.3100
# Epoch 30/50
# 35157/35157 [==============================] - 97s 3ms/step - loss: 1.1576 - accuracy: 0.4161 - val_loss: 1.1175 - val_accuracy: 0.3089
# Epoch 31/50
# 35157/35157 [==============================] - 97s 3ms/step - loss: 1.1579 - accuracy: 0.4162 - val_loss: 1.1179 - val_accuracy: 0.3101
# Epoch 32/50
# 35157/35157 [==============================] - 97s 3ms/step - loss: 1.1581 - accuracy: 0.4164 - val_loss: 1.1181 - val_accuracy: 0.3097
# Epoch 33/50
# 35157/35157 [==============================] - 97s 3ms/step - loss: 1.1584 - accuracy: 0.4165 - val_loss: 1.1188 - val_accuracy: 0.3104
# Epoch 34/50
# 35157/35157 [==============================] - 97s 3ms/step - loss: 1.1587 - accuracy: 0.4164 - val_loss: 1.1180 - val_accuracy: 0.3104
# Epoch 35/50
# 35157/35157 [==============================] - 97s 3ms/step - loss: 1.1588 - accuracy: 0.4166 - val_loss: 1.1185 - val_accuracy: 0.3107
# Epoch 36/50
# 35157/35157 [==============================] - 97s 3ms/step - loss: 1.1592 - accuracy: 0.4167 - val_loss: 1.1189 - val_accuracy: 0.3107
# Epoch 37/50
# 35157/35157 [==============================] - 97s 3ms/step - loss: 1.1595 - accuracy: 0.4166 - val_loss: 1.1186 - val_accuracy: 0.3101
# Epoch 38/50
# 35157/35157 [==============================] - 97s 3ms/step - loss: 1.1595 - accuracy: 0.4170 - val_loss: 1.1188 - val_accuracy: 0.3105
# Epoch 39/50
# 35157/35157 [==============================] - 97s 3ms/step - loss: 1.1598 - accuracy: 0.4169 - val_loss: 1.1196 - val_accuracy: 0.3114
# Epoch 40/50
# 35157/35157 [==============================] - 97s 3ms/step - loss: 1.1600 - accuracy: 0.4170 - val_loss: 1.1193 - val_accuracy: 0.3111
# Epoch 41/50
# 35157/35157 [==============================] - 97s 3ms/step - loss: 1.1601 - accuracy: 0.4170 - val_loss: 1.1197 - val_accuracy: 0.3111
# Epoch 42/50
# 30673/35157 [=========================>....] - ETA: 11s - loss: 1.1596 - accuracy: 0.4176

# %%
# Evaluate the model on the test data using `evaluate`
print("Evaluate on test data")
results = model.evaluate(x=[test_df.user_id, test_df.item_id],
                    y=test_df.rating, batch_size=128)
print("test loss, test acc:", results)

# Generate predictions (probabilities -- the output of the last layer)
# on new data using `predict`
# print("Generate predictions for 3 samples")
# predictions = model.predict(X_test[:3])
# print("predictions shape:", predictions.shape)

# %%
output = model.predict(x=[test_df.user_id, test_df.item_id])

# %%
plt.plot(history.history["loss"][5:])
plt.plot(history.history["val_loss"][5:])
plt.title("model loss")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.legend(["train", "test"], loc="upper left")
plt.show()

# %%
test_df.shape

# %%
output

# %%
output = np.argmax(output,axis =1)
output1 = np.array(output).flatten()

# %%
np.array(output1)
test_ratings = np.array(test_df.rating.copy())
print(test_ratings.shape)
for i in range(test_ratings.shape[0]):
    if test_ratings[i]>=4:
        test_ratings[i] = 1
    else:
        test_ratings[i]=0
test_ratings

# %%
test_ratings.shape

# %%
output1.shape

# %%
test_ratings

# %%
output1

# %%
sum(output1)

# %%
from sklearn.metrics import roc_auc_score
roc_auc_score (test_ratings, output1)

# %%
pd.Series(history.history['val_loss'][0:]).plot(logy=False)
plt.xlabel("Epoch")
plt.ylabel("Validation Error")
print('Minimum LOSS: ', min(history.history['val_loss']))

# %%
from IPython.display import SVG
from tensorflow.keras.utils import model_to_dot
SVG(model_to_dot(model,  show_shapes=True, show_layer_names=True).create(prog='dot', format='svg'))
